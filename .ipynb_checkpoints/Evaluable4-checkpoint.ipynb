# %% [markdown]
# # Actividad Evaluable 4: Patrones con K-means

# %% [markdown]
# ## Integrantes:
# **Rosa Vanessa Palacios Beltrán | A01652612**
#
# **Diego Reyna Reyes | A01657387**
#
# **José Roberto Garduño Cerecedo | A01656294**
#
# **Luis Angel Gonzalez Tapia| A01654625**
#
# **Samuel Sandoval Delgado | A01656191**
#
# **Daniel Rong Chen | A01656992**

# %% [markdown]
# Para esta actividad se detectarán los patrones con la técnica de clustering **K-means** usando los datos del archivo avocado.csv

# %% [markdown]
# 1. Cargar tus datos

# %%
#Importar las librerias para el analisis
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
from sklearn.cluster import KMeans
from sklearn.metrics import pairwise_distances_argmin_min
from sklearn import preprocessing

# %matplotlib inline
from mpl_toolkits.mplot3d import Axes3D
plt.rcParams['figure.figsize'] = (16, 9)
plt.style.use('ggplot')

# %%
dataframe = pd.read_csv(r"avocado.csv")
dataframe.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# 3  2015  Albany
# 4  2015  Albany

# %% [markdown]
# 2. Si determinas que alguna variable no sirve basándose en la actividad pasada, elimínala y justifica por qué quitaste o no variables.

# %% [markdown]
# El archivo avocado contiene 14 categorias:
#
#
# 1. Date
# 2. AveragePrice
# 3. Type
# 4. Year
# 5. Region
# 6. Total Volumen
# 7. 4046
# 8. 4225
# 9. 4770
# 10. Unnamed
# 11. Total Bags
# 12. Small Bags
# 13. Large Bags
# 14. XLarge Bags
#
#
#
#
#
#
# Para esta actividad solo tendrémos en cuenta 3 variables:
#
#
# *   AveragePrice
# *   Unnamed: Número de la semana del año
# *   Year
#
# Esto porque es nos ayuda a poder determinar valores de compra y producción deacuerdo al tiempo.
#
# La decisión de usar las tres variables anteriormente mencionadas fueron basandonos en el Hisograma a continuación:

# %%
dataframe.drop(['region'],1).hist()
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_24656\195625964.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   dataframe.drop(['region'],1).hist()

# %%
print(dataframe["AveragePrice"].shape)
# Out:
# (18249,)

# %%
print(dataframe["Unnamed: 0"].shape)
# Out:
# (18249,)

# %%
print(dataframe["year"].shape)
# Out:
# (18249,)

# %%
sb.pairplot(dataframe.dropna(), hue='type',height=4,vars=["AveragePrice","year","Unnamed: 0"],kind='scatter')

# %%
X = np.array(dataframe[["AveragePrice","year","Unnamed: 0"]])
y = np.array(dataframe['type'])
X.shape
# Out:
# (18249, 3)

# %%
fig = plt.figure()
ax = Axes3D(fig)
ax = fig.add_subplot(111, projection='3d')
colores=['blue','red']
asignar=[]

le = preprocessing.LabelEncoder()
le.fit(y)
y = le.transform(y)
for row in y:
    asignar.append(colores[row])
ax.scatter(X[:, 0], X[:, 1], X[:, 2], c=asignar,s=60)

# %% [markdown]
#  3. Determina un valor de k.

# %%
Nc = range(1, 20)
kmeans = [KMeans(n_clusters=i) for i in Nc]
kmeans
score = [kmeans[i].fit(X).score(X) for i in range(len(kmeans))]
score
plt.plot(Nc,score)
plt.xlabel('Number of Clusters')
plt.ylabel('Score')
plt.title('Elbow Curve')
plt.show()
# Out:
# C:\Users\HP\anaconda3\envs\ArteDeLaAnalitica\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\HP\anaconda3\envs\ArteDeLaAnalitica\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\HP\anaconda3\envs\ArteDeLaAnalitica\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\HP\anaconda3\envs\ArteDeLaAnalitica\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\HP\anaconda3\envs\ArteDeLaAnalitica\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\HP\anaconda3\envs\ArteDeLaAnalitica\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\HP\anaconda3\envs\ArteDeLaAnalitica\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\HP\anaconda3\envs\ArteDeLaAnalitica\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\HP\anaconda3\envs\ArteDeLaAnalitica\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\HP\anaconda3\envs\ArteDeLaAnalitica\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\HP\anaconda3\envs\ArteDeLaAnalitica\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\HP\anaconda3\envs\ArteDeLaAnalitica\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\HP\anaconda3\envs\ArteDeLaAnalitica\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\HP\anaconda3\envs\ArteDeLaAnalitica\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\HP\anaconda3\envs\ArteDeLaAnalitica\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\HP\anaconda3\envs\ArteDeLaAnalitica\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\HP\anaconda3\envs\ArteDeLaAnalitica\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\HP\anaconda3\envs\ArteDeLaAnalitica\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\HP\anaconda3\envs\ArteDeLaAnalitica\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %% [markdown]
# Con la gráfica anterior decidimos que el valor de K sea 5 porque es nuestro "punto de codo".

# %% [markdown]
# 4. Utilizando scikitlearn calcula los centros del algoritmo k-means.

# %%
kmeans = KMeans(n_clusters=5).fit(X)
centroids = kmeans.cluster_centers_
print(centroids)
# Out:
# C:\Users\HP\anaconda3\envs\ArteDeLaAnalitica\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# [[1.55340800e+00 2.01606452e+03 1.53548387e+01]
#  [1.29031616e+00 2.01602916e+03 4.61722540e+01]
#  [1.40484848e+00 2.01650000e+03 5.00000000e+00]
#  [1.35595062e+00 2.01600000e+03 3.55000000e+01]
#  [1.43629630e+00 2.01600000e+03 2.55000000e+01]]

# %%
dist_c = np.zeros((5,5))
for i,c1 in enumerate(centroids):
  for j,c2 in enumerate(centroids):
    dist_c[i,j] = np.sqrt((c1[0]-c2[0])**2+(c1[1]-c2[1])**2+(c1[2]-c2[2])**2)
print(dist_c)
# Out:
# [[ 0.         30.81855859 10.36505672 20.14623228 10.14604234]
#  [30.81855859  0.         41.17510542 10.67249569 20.67279001]
#  [10.36505672 41.17510542  0.         30.50413728 20.50612077]
#  [20.14623228 10.67249569 30.50413728  0.         10.00032277]
#  [10.14604234 20.67279001 20.50612077 10.00032277  0.        ]]

# %%
# Predicting the clusters
labels = kmeans.predict(X)
# Getting the cluster centers
C = kmeans.cluster_centers_
colores=['red','green','blue','cyan','yellow']
asignar=[]
for row in labels:
    asignar.append(colores[row])

fig = plt.figure()
ax = Axes3D(fig)
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X[:, 0], X[:, 1], X[:, 2], c=asignar,s=60)
ax.scatter(C[:, 0], C[:, 1], C[:, 2], marker='*', c=colores, s=1000)

# %% [markdown]
# # Conclusiones

# %% [markdown]
# #### José Roberto Garduño Cerecedo A01656294

# %% [markdown]
# ####
